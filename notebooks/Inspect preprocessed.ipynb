# %%
import os
import sys
import random
import numpy as np
sys.path.append('/home/mingot/lung_cancer_ds_bowl/src')
from utils import plotting

# %%
p1 = np.load("/home/shared/output/resnet/v19/dsb_ffe02fe7d2223743f7fb455dfaff3842.npz")['arr_0']
print p1.shape
#plotting.multiplot(p1[1])
#p2 = np.load("/home/shared/output/resnet/v19/dsb_ffe02fe7d2223743f7fb455dfaff3842_or.npz")['arr_0']
#plotting.multiplot(p2[1])
#print p2.shape
# Out:
# (2, 173, 512, 512)

# %%
patients = os.listdir('/mnt/hd2/preprocessed_stage2/')

for idx, pp in enumerate(patients[300:400]):
    #pp = random.choice(patients)
    pdata = np.load('/mnt/hd2/preprocessed_stage2/%s' % pp)['arr_0']
    print "Patient: %s (%d), shape: %s" % (pp, idx, str(pdata.shape))
    #plotting.multiplot(pdata[0])
    plotting.multiplot(pdata[1])
# Out:
# Patient: dsb_5df13e26655687c40cfb724cffc27255.npz (0), shape: (2, 163, 512, 512)
# Patient: dsb_97434189865e083f8f553e3a922b927a.npz (1), shape: (2, 122, 512, 512)
# Patient: dsb_41b47383fb53e8ed474be0aa123eb73c.npz (2), shape: (2, 160, 512, 512)
# Patient: dsb_9417377a5aeb266804c605ab3b11c916.npz (3), shape: (2, 174, 512, 512)
# Patient: dsb_bfa308aee025f633de3c9c727b40bec1.npz (4), shape: (2, 158, 512, 512)
# Patient: dsb_4ccaa4579f598e1874301917ba11c897.npz (5), shape: (2, 179, 512, 512)
# Patient: dsb_1c9a8b9ee193c5f967c6299e961e3dac.npz (6), shape: (2, 158, 512, 512)
# Patient: dsb_f25d655012762acc9898a41b29e008e3.npz (7), shape: (2, 149, 512, 512)
# Patient: dsb_4e89f25452c29ce839596c9297452eac.npz (8), shape: (2, 166, 512, 512)
# Patient: dsb_0997c605045ff2b3a410fcf03de497a6.npz (9), shape: (2, 171, 512, 512)
# Patient: dsb_d7f86fbd451c55c5787c531ee97ba519.npz (10), shape: (2, 162, 512, 512)
# Patient: dsb_ad9877d7153ba81280cf6fda3ec258ec.npz (11), shape: (2, 166, 512, 512)
# ...
